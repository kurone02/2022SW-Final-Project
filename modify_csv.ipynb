# %%
# !pip install pandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (1.3.5)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas) (1.21.6)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas) (2022.2.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)

# %%
import pandas as pd

# %%
# !pip install numpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (1.21.6)

# %%
import numpy as np

# %%
pd.read_csv("data.csv")
# Out:
#      header__reqNo  header__resultCode header__resultMsg  \
# 0       32069376.0                 0.0   NORMAL SERVICE.
# 1              NaN                 NaN               NaN
# 2              NaN                 NaN               NaN
# 3              NaN                 NaN               NaN
# 4              NaN                 NaN               NaN
# ..             ...                 ...               ...
# 195            NaN                 NaN               NaN
# 196            NaN                 NaN               NaN
# 197            NaN                 NaN               NaN
# 198            NaN                 NaN               NaN
# 199            NaN                 NaN               NaN
#
#      body__items__item__desertionNo  \
# 0                   444450202101068
# 1                   441559202101292
# 2                   426328202100505
# 3                   411306202100780
# 4                   450650202105368
# ..                              ...
# 195                 441394202103027
# 196                 441394202103026
# 197                 441394202103025
# 198                 441394202103023
# 199                 441393202102474
#
#                            body__items__item__filename  \
# 0    http://www.animal.go.kr/files/shelter/2021/12/...
# 1    http://www.animal.go.kr/files/shelter/2021/12/...
# 2    http://www.animal.go.kr/files/shelter/2021/12/...
# 3    http://www.animal.go.kr/files/shelter/2021/12/...
# 4    http://www.animal.go.kr/files/shelter/2021/12/...
# ..                                                 ...
# 195  http://www.animal.go.kr/files/shelter/2021/12/...
# 196  http://www.animal.go.kr/files/shelter/2021/12/...
# 197  http://www.animal.go.kr/files/shelter/2021/12/...
# 198  http://www.animal.go.kr/files/shelter/2021/12/...
# 199  http://www.animal.go.kr/files/shelter/2022/01/...
#
#      body__items__item__happenDt body__items__item__happenPlace  \
# 0                       20211231                      공주시 우금티터널
# 1                       20211231            장흥면 유원지로 89번길 90 인근
# 2                       20211231                        영도 동물병원
# 3                       20211231                 동일로 140길 33 인근
# 4                       20211231              제주시 삼도일동 서사로 4길 3
# ..                           ...                            ...
# 195                     20211231                   선유동 367-1 부근
# 196                     20211231                   선유동 367-1 부근
# 197                     20211231                   선유동 367-1 부근
# 198                     20211231                   선유동 367-1 부근
# 199                     20211231                     안산소방서에서 인수
#
#     body__items__item__kindCd body__items__item__colorCd  \
# 0                     [개] 믹스견                         갈색
# 1                     [개] 말티즈                          흰
# 2                      [개] 푸들                         흰색
# 3                [고양이] 한국 고양이                          검
# 4                [고양이] 한국 고양이                         회색
# ..                        ...                        ...
# 195                   [개] 믹스견                         황색
# 196                   [개] 믹스견                         황색
# 197                   [개] 믹스견                   검정,황색,흰색
# 198                   [개] 믹스견                      갈색,검정
# 199                    [개] 시바                         갈백
#
#     body__items__item__age  ... body__items__item__careNm  \
# 0                 2019(년생)  ...                 공주시 동물보호소
# 1                 2020(년생)  ...                한국동물구조관리협회
# 2                 2020(년생)  ...                     하얀비둘기
# 3                 2020(년생)  ...                한국동물구조관리협회
# 4                 2021(년생)  ...                 제주 동물보호센터
# ..                     ...  ...                       ...
# 195               2019(년생)  ...                 고양시동물보호센터
# 196               2018(년생)  ...                 고양시동물보호센터
# 197               2018(년생)  ...                 고양시동물보호센터
# 198               2018(년생)  ...                 고양시동물보호센터
# 199               2022(년생)  ...                한국야생동물보호협회
#
#     body__items__item__careTel  \
# 0                 041-853-7575
# 1                 031-867-9119
# 2                 051-293-9779
# 3                 031-867-9119
# 4                 064-710-4065
# ..                         ...
# 195               031-962-3232
# 196               031-962-3232
# 197               031-962-3232
# 198               031-962-3232
# 199               031-296-0124
#
#                            body__items__item__careAddr  \
# 0                                충청남도 공주시 감영길 7 (반죽동)
# 1                          경기도 양주시 남면 감악산로 63-37 (남면)
# 2                             부산광역시 강서구 제도로 726 (강동동)
# 3                               경기도 양주시 남면 감악산로 63-37
# 4                       제주특별자치도 제주시 첨단동길 184-14 (용강동)
# ..                                                 ...
# 195  경기도 고양시 덕양구 고양대로 1695 (원흥동, 고양시 농업기술센터) 고양시동물보호센터
# 196  경기도 고양시 덕양구 고양대로 1695 (원흥동, 고양시 농업기술센터) 고양시동물보호센터
# 197  경기도 고양시 덕양구 고양대로 1695 (원흥동, 고양시 농업기술센터) 고양시동물보호센터
# 198  경기도 고양시 덕양구 고양대로 1695 (원흥동, 고양시 농업기술센터) 고양시동물보호센터
# 199         경기도 안산시 상록구 청곡길 50 (부곡동) 안산시 상록구 부곡동 231-5
#
#      body__items__item__orgNm body__items__item__chargeNm  \
# 0                    충청남도 공주시                       축산유통팀
# 1                     경기도 양주시                   양주시 동물보호팀
# 2                   부산광역시 영도구                         유혜정
# 3                   서울특별시 중랑구                         김가희
# 4                     제주특별자치도                    제주동물보호센터
# ..                        ...                         ...
# 195                   경기도 고양시                 조재현(유기동물보호)
# 196                   경기도 고양시                 조재현(유기동물보호)
# 197                   경기도 고양시                 조재현(유기동물보호)
# 198                   경기도 고양시                 조재현(유기동물보호)
# 199                   경기도 안산시                   안산시 농업정책과
#
#     body__items__item__officetel body__items__item__noticeComment  \
# 0                   041-840-8580                              NaN
# 1                  031-8082-7361                              NaN
# 2                   051-419-6211                              NaN
# 3                   02-2094-0753                              NaN
# 4                   064-710-4065                              NaN
# ..                           ...                              ...
# 195                031-8075-4657                              NaN
# 196                031-8075-4657                              NaN
# 197                031-8075-4657                              NaN
# 198                031-8075-4657                              NaN
# 199                 031-481-2494                              NaN
#
#     body__numOfRows body__pageNo body__totalCount
# 0             200.0          1.0           8309.0
# 1               NaN          NaN              NaN
# 2               NaN          NaN              NaN
# 3               NaN          NaN              NaN
# 4               NaN          NaN              NaN
# ..              ...          ...              ...
# 195             NaN          NaN              NaN
# 196             NaN          NaN              NaN
# 197             NaN          NaN              NaN
# 198             NaN          NaN              NaN
# 199             NaN          NaN              NaN
#
# [200 rows x 29 columns]

# %%
df = pd.read_csv("data.csv")

# %%
df.head()
# Out:
#    header__reqNo  header__resultCode header__resultMsg  \
# 0     32069376.0                 0.0   NORMAL SERVICE.
# 1            NaN                 NaN               NaN
# 2            NaN                 NaN               NaN
# 3            NaN                 NaN               NaN
# 4            NaN                 NaN               NaN
#
#    body__items__item__desertionNo  \
# 0                 444450202101068
# 1                 441559202101292
# 2                 426328202100505
# 3                 411306202100780
# 4                 450650202105368
#
#                          body__items__item__filename  \
# 0  http://www.animal.go.kr/files/shelter/2021/12/...
# 1  http://www.animal.go.kr/files/shelter/2021/12/...
# 2  http://www.animal.go.kr/files/shelter/2021/12/...
# 3  http://www.animal.go.kr/files/shelter/2021/12/...
# 4  http://www.animal.go.kr/files/shelter/2021/12/...
#
#    body__items__item__happenDt body__items__item__happenPlace  \
# 0                     20211231                      공주시 우금티터널
# 1                     20211231            장흥면 유원지로 89번길 90 인근
# 2                     20211231                        영도 동물병원
# 3                     20211231                 동일로 140길 33 인근
# 4                     20211231              제주시 삼도일동 서사로 4길 3
#
#   body__items__item__kindCd body__items__item__colorCd body__items__item__age  \
# 0                   [개] 믹스견                         갈색               2019(년생)
# 1                   [개] 말티즈                          흰               2020(년생)
# 2                    [개] 푸들                         흰색               2020(년생)
# 3              [고양이] 한국 고양이                          검               2020(년생)
# 4              [고양이] 한국 고양이                         회색               2021(년생)
#
#    ... body__items__item__careNm body__items__item__careTel  \
# 0  ...                 공주시 동물보호소               041-853-7575
# 1  ...                한국동물구조관리협회               031-867-9119
# 2  ...                     하얀비둘기               051-293-9779
# 3  ...                한국동물구조관리협회               031-867-9119
# 4  ...                 제주 동물보호센터               064-710-4065
#
#       body__items__item__careAddr  body__items__item__orgNm  \
# 0           충청남도 공주시 감영길 7 (반죽동)                   충청남도 공주시
# 1     경기도 양주시 남면 감악산로 63-37 (남면)                    경기도 양주시
# 2        부산광역시 강서구 제도로 726 (강동동)                  부산광역시 영도구
# 3          경기도 양주시 남면 감악산로 63-37                  서울특별시 중랑구
# 4  제주특별자치도 제주시 첨단동길 184-14 (용강동)                    제주특별자치도
#
#   body__items__item__chargeNm body__items__item__officetel  \
# 0                       축산유통팀                 041-840-8580
# 1                   양주시 동물보호팀                031-8082-7361
# 2                         유혜정                 051-419-6211
# 3                         김가희                 02-2094-0753
# 4                    제주동물보호센터                 064-710-4065
#
#   body__items__item__noticeComment body__numOfRows body__pageNo  \
# 0                              NaN           200.0          1.0
# 1                              NaN             NaN          NaN
# 2                              NaN             NaN          NaN
# 3                              NaN             NaN          NaN
# 4                              NaN             NaN          NaN
#
#   body__totalCount
# 0           8309.0
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
#
# [5 rows x 29 columns]

# %%
df.columns
# Out:
# Index(['header__reqNo', 'header__resultCode', 'header__resultMsg',
#        'body__items__item__desertionNo', 'body__items__item__filename',
#        'body__items__item__happenDt', 'body__items__item__happenPlace',
#        'body__items__item__kindCd', 'body__items__item__colorCd',
#        'body__items__item__age', 'body__items__item__weight',
#        'body__items__item__noticeNo', 'body__items__item__noticeSdt',
#        'body__items__item__noticeEdt', 'body__items__item__popfile',
#        'body__items__item__processState', 'body__items__item__sexCd',
#        'body__items__item__neuterYn', 'body__items__item__specialMark',
#        'body__items__item__careNm', 'body__items__item__careTel',
#        'body__items__item__careAddr', 'body__items__item__orgNm',
#        'body__items__item__chargeNm', 'body__items__item__officetel',
#        'body__items__item__noticeComment', 'body__numOfRows', 'body__pageNo',
#        'body__totalCount'],
#       dtype='object')

# %%
modify_col = ["body__items__item__happenDt", "body__items__item__noticeSdt", "body__items__item__noticeEdt"]

# %%
df[modify_col]
# Out:
#      body__items__item__happenDt  body__items__item__noticeSdt  \
# 0                       20211231                      20220104
# 1                       20211231                      20220104
# 2                       20211231                      20220104
# 3                       20211231                      20220104
# 4                       20211231                      20220103
# ..                           ...                           ...
# 195                     20211231                      20211231
# 196                     20211231                      20211231
# 197                     20211231                      20211231
# 198                     20211231                      20211231
# 199                     20211231                      20211231
#
#      body__items__item__noticeEdt
# 0                        20220117
# 1                        20220114
# 2                        20220114
# 3                        20220124
# 4                        20220113
# ..                            ...
# 195                      20220110
# 196                      20220110
# 197                      20220110
# 198                      20220110
# 199                      20220110
#
# [200 rows x 3 columns]

# %%
df[modify_col]
# Out:
#      body__items__item__happenDt  body__items__item__noticeSdt  \
# 0                       20211231                      20220104
# 1                       20211231                      20220104
# 2                       20211231                      20220104
# 3                       20211231                      20220104
# 4                       20211231                      20220103
# ..                           ...                           ...
# 195                     20211231                      20211231
# 196                     20211231                      20211231
# 197                     20211231                      20211231
# 198                     20211231                      20211231
# 199                     20211231                      20211231
#
#      body__items__item__noticeEdt
# 0                        20220117
# 1                        20220114
# 2                        20220114
# 3                        20220124
# 4                        20220113
# ..                            ...
# 195                      20220110
# 196                      20220110
# 197                      20220110
# 198                      20220110
# 199                      20220110
#
# [200 rows x 3 columns]

# %%
df[modify_col[0]][1]
# Out:
# 20211231

# %%
for col in modify_col:
    for i in range(len(df[col])):
        temp = str(df[col][i])
        df[col][i] = f"{temp[:4]}-{temp[4:6]}-{temp[6:]}"
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
df[modify_col]
# Out:
#     body__items__item__happenDt body__items__item__noticeSdt  \
# 0                    2021-12-31                   2022-01-04
# 1                    2021-12-31                   2022-01-04
# 2                    2021-12-31                   2022-01-04
# 3                    2021-12-31                   2022-01-04
# 4                    2021-12-31                   2022-01-03
# ..                          ...                          ...
# 195                  2021-12-31                   2021-12-31
# 196                  2021-12-31                   2021-12-31
# 197                  2021-12-31                   2021-12-31
# 198                  2021-12-31                   2021-12-31
# 199                  2021-12-31                   2021-12-31
#
#     body__items__item__noticeEdt
# 0                     2022-01-17
# 1                     2022-01-14
# 2                     2022-01-14
# 3                     2022-01-24
# 4                     2022-01-13
# ..                           ...
# 195                   2022-01-10
# 196                   2022-01-10
# 197                   2022-01-10
# 198                   2022-01-10
# 199                   2022-01-10
#
# [200 rows x 3 columns]

# %%
df.to_csv("modified_data.csv", encoding='utf-8')
